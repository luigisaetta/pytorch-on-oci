# %% [markdown]
# ### First tests with YOLO V5
# * taken from: https://github.com/ultralytics/yolov5

# %%
import torch

# %%
# check that access to GPU is OK
torch.cuda.is_available()
# Out:
# True

# %%
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or yolov5n - yolov5x6, custom
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /home/datascience/.cache/torch/hub/master.zip
# YOLOv5 🚀 2022-10-17 Python-3.7.8 torch-1.10.0 CUDA:0 (Tesla P100-SXM2-16GB, 16281MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.2/yolov5s.pt to yolov5s.pt...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# Images
img = 'https://ultralytics.com/images/zidane.jpg'

# %%
# Inference
results = model(img)

# Results
results.print()
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 646.9ms pre-process, 15.9ms inference, 2.5ms NMS per image at shape (1, 3, 384, 640)

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F0C4216C8D0>
