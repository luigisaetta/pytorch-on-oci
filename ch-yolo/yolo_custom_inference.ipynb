# %% [markdown]
# ### Inference with a custom model
# * inspired from: https://github.com/ultralytics/yolov5

# %%
import torch

# %%
# check that access to GPU is OK
torch.cuda.is_available()
# Out:
# True

# %%
# Model path: the dir with best.pt from training
MODEL_PATH = "/home/datascience/yolov5/runs/train/exp5/weights/best.pt"

model = torch.hub.load("ultralytics/yolov5", "custom", path=MODEL_PATH)
# Out:
# Using cache found in /home/datascience/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-10-17 Python-3.7.8 torch-1.10.0 CUDA:0 (Tesla P100-SXM2-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
# Images
img = './parcel11.jpg'

# %%
# Inference
results = model(img)

# Results
results.print()
# Out:
# image 1/1: 445x386 2 barcodes
# Speed: 14.5ms pre-process, 15.3ms inference, 2.0ms NMS per image at shape (1, 3, 640, 576)

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=386x445 at 0x7F9D3A33DB10>
